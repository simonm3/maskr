# %%
from maskr.ipstartup import *
from maskr.utils import visualize
from maskr.baseline import rngreset
from maskr.samples.nuke.config import Config
from maskr.samples.nuke.learner import get_learn

class Config(Config):
    #COMPAT = True
    #AUGMENT = False
    #SHUFFLE = False
    #WORKERS = 0
    BATCH_SIZE=3
    GPU_COUNT=1
config = Config()
rngreset()
# Out:
# [root:INFO]: (ipstartup.py:34, time=20:17)
# <style>audio{display:none}</style>

# %%
learn = get_learn(config)
# Out:
# [root:INFO]:starting (cellevents.py:36, time=20:17)
# [root:INFO]:train    505
# valid    123
# Name: subset, dtype: int64 (learner.py:22, time=20:17)
# time: 4.46 s

# %%
learn.lr_find()

# %%
learn.recorder.plot()
# Out:
# [root:INFO]:starting (cellevents.py:36, time=18:08)
# time: 812 ms

# %%
learn.fit(1, .01)
# Out:
# Total time: 19:42
# epoch  train_loss  valid_loss
# 1      1.000148    1.012466    (19:41)
# time: 19min 42s
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <style>audio{display:none}</style>

# %%
learn.save("nukemodel3")
# Out:
# [root:INFO]:starting (cellevents.py:36, time=20:38)
# time: 1.99 s
